# %%
import pandas as pd
pd.to_datetime('2020-10-6')
# Out:
# Timestamp('2020-10-06 00:00:00')

# %%
pd.to_datetime('6 Oct 2020 5:20pm')
# Out:
# Timestamp('2020-10-06 17:20:00')

# %%
pd.to_datetime('2020/10/6 5:20pm')
# Out:
# Timestamp('2020-10-06 17:20:00')

# %%
pd.to_datetime('10-6-2020')
# Out:
# Timestamp('2020-10-06 00:00:00')

# %%
pd.to_datetime('10-6-2020', dayfirst=True)
# Out:
# Timestamp('2020-06-10 00:00:00')

# %%
pd.to_datetime('1-6-2020', format='%d-%m-%Y')
# Out:
# Timestamp('2020-06-01 00:00:00')

# %%
pd.to_datetime('1/6/2020', format='%d/%m/%Y')
# Out:
# Timestamp('2020-06-01 00:00:00')

# %%
pd.to_datetime(['2020-6-2','2020-6-3','2020-6-8'], format='%Y-%m-%d')
# Out:
# DatetimeIndex(['2020-06-02', '2020-06-03', '2020-06-08'], dtype='datetime64[ns]', freq=None)

# %%
#pd.to_datetime('10-6-2563')

# %%
# ws01
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = 11,3

# %%
df = pd.read_csv('data/opsd_germany_daily.csv')

# %%
df.head()
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN
# 3  2006-01-04     1457.217   NaN    NaN         NaN
# 4  2006-01-05     1477.131   NaN    NaN         NaN

# %%
df.tail()
# Out:
#             Date  Consumption     Wind   Solar  Wind+Solar
# 4378  2017-12-27   1263.94091  394.507  16.530     411.037
# 4379  2017-12-28   1299.86398  506.424  14.162     520.586
# 4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382  2017-12-31   1107.11488  721.176  19.980     741.156

# %%
df.sample(5)
# Out:
#             Date  Consumption     Wind    Solar  Wind+Solar
# 2839  2013-10-10   1375.58500   51.156   36.995      88.151
# 3181  2014-09-17   1439.67100  104.751  146.901     251.652
# 3601  2015-11-11   1521.93200  385.009   44.773     429.782
# 4329  2017-11-08   1547.48171   62.667   18.332      80.999
# 1559  2010-04-09   1363.00700   86.467      NaN         NaN

# %%
df.describe()
# Out:
#        Consumption         Wind        Solar   Wind+Solar
# count  4383.000000  2920.000000  2188.000000  2187.000000
# mean   1338.675836   164.814173    89.258695   272.663481
# std     165.775710   143.692732    58.550099   146.319884
# min     842.395000     5.757000     1.968000    21.478000
# 25%    1217.859000    62.353250    35.179250   172.185500
# 50%    1367.123000   119.098000    86.407000   240.991000
# 75%    1457.761000   217.900250   135.071500   338.988000
# max    1709.568000   826.278000   241.580000   851.556000

# %%
df.shape
# Out:
# (4383, 5)

# %%
df.isnull().sum()
# Out:
# Date              0
# Consumption       0
# Wind           1463
# Solar          2195
# Wind+Solar     2196
# dtype: int64

# %%
# ws02
# plt.rcParams['figure.figsize'] = 11,3 
# df.plot()
df.plot(grid=True, lw=0.5, figsize=(10,3)) # 
plt.xlabel('Date')
plt.ylabel('Power GWh')
plt.show()

# %%
# ws03
df.dtypes
# Out:
# Date            object
# Consumption    float64
# Wind           float64
# Solar          float64
# Wind+Solar     float64
# dtype: object

# %%
df.Date = pd.to_datetime(df.Date, format='%Y-%m-%d')

# %%
df.head()
# Out:
#         Date  Consumption  Wind  Solar  Wind+Solar
# 0 2006-01-01     1069.184   NaN    NaN         NaN
# 1 2006-01-02     1380.521   NaN    NaN         NaN
# 2 2006-01-03     1442.533   NaN    NaN         NaN
# 3 2006-01-04     1457.217   NaN    NaN         NaN
# 4 2006-01-05     1477.131   NaN    NaN         NaN

# %%
df.set_index('Date', inplace=True)

# %%
df.index[:10]
# Out:
# DatetimeIndex(['2006-01-01', '2006-01-02', '2006-01-03', '2006-01-04',
#                '2006-01-05', '2006-01-06', '2006-01-07', '2006-01-08',
#                '2006-01-09', '2006-01-10'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
df.plot(lw=0.5)
# Out:
# <Axes: xlabel='Date'>

# %%
df.loc['2016-1':'2016-3'].plot(grid=True)
plt.ylabel('Power (GWh)');
plt.show()

# %%
df.plot(marker='.', linestyle='None', figsize=(11,8), subplots=True, grid=True)
plt.show()

# %%
df.plot(lw=0.5,figsize=(11,8),subplots=True)
plt.show()

# %%
cols_plot = ['Consumption', 'Solar', 'Wind']
df[cols_plot].plot(marker='.', alpha=0.8, linestyle='None', figsize=(11, 9), subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
# ws04
df.loc['2017-1-5']
# Out:
# Consumption    1547.238
# Wind            261.758
# Solar            20.797
# Wind+Solar      282.555
# Name: 2017-01-05 00:00:00, dtype: float64

# %%
df.loc['2017-1'] #
# Out:
#             Consumption     Wind   Solar  Wind+Solar
# Date
# 2017-01-01     1130.413  307.125  35.291     342.416
# 2017-01-02     1441.052  295.099  12.479     307.578
# 2017-01-03     1529.990  666.173   9.351     675.524
# 2017-01-04     1553.083  686.578  12.814     699.392
# 2017-01-05     1547.238  261.758  20.797     282.555
# 2017-01-06     1501.795  115.723  33.341     149.064
# 2017-01-07     1405.145  252.307   8.387     260.694
# 2017-01-08     1301.011   41.261   4.991      46.252
# 2017-01-09     1604.348  190.983   7.070     198.053
# 2017-01-10     1639.046  280.373  13.045     293.418
# 2017-01-11     1654.809  637.259   7.379     644.638
# 2017-01-12     1620.597  584.792  17.865     602.657
# 2017-01-13     1608.895  518.618  14.311     532.929
# 2017-01-14     1392.736  487.189  16.767     503.956
# 2017-01-15     1289.904  229.770  16.105     245.875
# 2017-01-16     1605.465   69.209  17.600      86.809
# 2017-01-17     1649.104   79.363  22.909     102.272
# 2017-01-18     1669.395  148.915  22.709     171.624
# 2017-01-19     1667.477  121.272  38.191     159.463
# 2017-01-20     1641.737  109.383  39.633     149.016
# 2017-01-21     1423.020   78.893  45.477     124.370
# 2017-01-22     1340.341   50.774  47.386      98.160
# 2017-01-23     1663.492   39.710  30.939      70.649
# 2017-01-24     1682.002   31.375  10.300      41.675
# 2017-01-25     1674.171   70.772  17.720      88.492
# 2017-01-26     1659.527  235.128  56.487     291.615
# 2017-01-27     1629.164  254.270  68.625     322.895
# 2017-01-28     1394.033  208.827  65.964     274.791
# 2017-01-29     1296.170  304.952  53.854     358.806
# 2017-01-30     1605.356  338.292  18.577     356.869
# 2017-01-31     1620.860  124.784  12.064     136.848

# %%
df.loc['2017']
df.loc['2017'].count()
df.loc['2017'].head()
df.loc['2017'].tail()
# Out:
#             Consumption     Wind   Solar  Wind+Solar
# Date
# 2017-12-27   1263.94091  394.507  16.530     411.037
# 2017-12-28   1299.86398  506.424  14.162     520.586
# 2017-12-29   1295.08753  584.277  29.854     614.131
# 2017-12-30   1215.44897  721.247   7.467     728.714
# 2017-12-31   1107.11488  721.176  19.980     741.156

# %%
df.loc['2017-1-1':'2017-1-5']
# Out:
#             Consumption     Wind   Solar  Wind+Solar
# Date
# 2017-01-01     1130.413  307.125  35.291     342.416
# 2017-01-02     1441.052  295.099  12.479     307.578
# 2017-01-03     1529.990  666.173   9.351     675.524
# 2017-01-04     1553.083  686.578  12.814     699.392
# 2017-01-05     1547.238  261.758  20.797     282.555

# %%
date_range = pd.date_range('2017-1-1', periods=7, freq='d')
df.loc[date_range]
# Out:
#             Consumption     Wind   Solar  Wind+Solar
# 2017-01-01     1130.413  307.125  35.291     342.416
# 2017-01-02     1441.052  295.099  12.479     307.578
# 2017-01-03     1529.990  666.173   9.351     675.524
# 2017-01-04     1553.083  686.578  12.814     699.392
# 2017-01-05     1547.238  261.758  20.797     282.555
# 2017-01-06     1501.795  115.723  33.341     149.064
# 2017-01-07     1405.145  252.307   8.387     260.694

# %%
# ws05
cols_plot = ['Solar', 'Wind']
df[cols_plot].loc['2017'].plot(grid=True)
plt.ylabel('Power (GWh)');
plt.show()

# %%
cols_plot = ['Solar', 'Wind']
df[cols_plot].loc['2017-1':'2017-10'].plot(grid=True)
plt.ylabel('Power (GWh)');
plt.show()

# %%
df.Consumption.loc['2016':'2017'].plot(grid=True)
plt.ylabel('Consumption (GWh)');

plt.show()

# %%
# ws06
start, end = '2017-12-1', '2017-12-7'
columns = ['Consumption', 'Wind', 'Solar'] 

df[columns][start : end].round(1)
# Out:
#             Consumption   Wind  Solar
# Date
# 2017-12-01       1593.0   52.3   19.3
# 2017-12-02       1391.9  126.3   16.5
# 2017-12-03       1330.3  387.5   12.4
# 2017-12-04       1621.0  479.8   10.7
# 2017-12-05       1643.7  611.5   11.0
# 2017-12-06       1639.1  632.5    7.6
# 2017-12-07       1628.5  743.7   43.0

# %%
df_weekly_roll = df[columns].rolling(7, center=True).mean()
df_weekly_roll[start : end].round(1)
# Out:
#             Consumption   Wind  Solar
# Date
# 2017-12-01       1538.9  246.7   16.7
# 2017-12-02       1543.0  260.5   15.5
# 2017-12-03       1548.0  336.6   13.1
# 2017-12-04       1549.6  433.4   17.2
# 2017-12-05       1553.2  519.2   17.4
# 2017-12-06       1556.6  602.9   16.8
# 2017-12-07       1554.8  636.5   16.4

# %%
df[columns][start : end].mean().round(1)
# Out:
# Consumption    1549.6
# Wind            433.4
# Solar            17.2
# dtype: float64

# %%
df.shape
# Out:
# (4383, 4)

# %%
df_weekly_roll.shape
# Out:
# (4383, 3)

# %%
# ws07

df_weekly_resampling = df[columns].resample('7d').mean()
df_weekly_resampling.tail().round(1)
# Out:
#             Consumption   Wind  Solar
# Date
# 2017-12-03       1556.6  602.9   16.8
# 2017-12-10       1546.8  495.7   17.8
# 2017-12-17       1462.6  258.8   10.3
# 2017-12-24       1208.2  617.7   17.8
# 2017-12-31       1107.1  721.2   20.0

# %%
df_weekly_resampling.shape
# Out:
# (627, 3)

# %%
df_weekly_resampling = df[columns].resample('q').mean()
df_weekly_resampling.tail().round(1)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9788\406290401.py:1: FutureWarning: 'q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   df_weekly_resampling = df[columns].resample('q').mean()
#             Consumption   Wind  Solar
# Date
# 2016-12-31       1428.3  249.1   37.9
# 2017-03-31       1483.4  300.2   61.3
# 2017-06-30       1318.7  229.7  157.6
# 2017-09-30       1304.5  187.8  136.6
# 2017-12-31       1426.2  407.2   37.6

# %%
df_weekly_resampling = df[columns].resample('m').sum()
df_weekly_resampling.tail().round(1)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9788\423610012.py:1: FutureWarning: 'm' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_weekly_resampling = df[columns].resample('m').sum()
#             Consumption     Wind   Solar
# Date
# 2017-08-31      40029.8   5499.8  4602.8
# 2017-09-30      40078.6   6287.7  3079.3
# 2017-10-31      42355.2  12480.1  2130.6
# 2017-11-30      44339.7  10259.0   831.0
# 2017-12-31      44511.1  14725.4   494.2

# %%
start, end = '2017-12-1', '2017-12-31'
df[columns][start : end].sum().round(1)
# Out:
# Consumption    44511.1
# Wind           14725.4
# Solar            494.2
# dtype: float64

# %%
# ws08
df_resampling = df[columns].resample('1w').mean()

df_resampling.plot(grid=True)
plt.ylabel('GWh');
plt.title('Power')
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9788\3756972401.py:2: FutureWarning: 'w' is deprecated and will be removed in a future version, please use 'W' instead.
#   df_resampling = df[columns].resample('1w').mean()

# %%
start, end = '2017-2','2017-10'
df.Solar.loc[start:end].plot(marker='o', label='Daily', markersize=2, alpha=0.7)
df.Solar.loc[start:end].resample('15d').mean().plot(marker='o', c='blue',
                                                 markersize=8, label='Mean Sampling')
df.Solar.loc[start:end].rolling(15, center=True).mean().plot(marker='o',
                                                 markersize=4, label='Mean Rolling')
plt.ylabel('Power (GWh)');
plt.title('Solar')
plt.legend()
plt.grid()
plt.show()

# %%
# ws09
columns = ['Solar','Wind']
yearly = df[columns].resample('y').sum()

yearly.plot(kind='bar', figsize=(10,3), rot=20)
plt.grid()
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9788\3813144615.py:3: FutureWarning: 'y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   yearly = df[columns].resample('y').sum()

# %%
columns = ['Solar','Wind']
yearly = df[columns].resample('y').sum()
    
def x_label(datetime):
    lb = str(datetime.year) 
    return lb

ax = yearly.plot(kind='bar', figsize=(10,3), rot=20)
ax.set_xticklabels(map(lambda x: x_label(x), yearly.index))
ax.set(xlabel="Year", ylabel="Power (GWh)")
ax.set(title="Yearly Power 2006-2018")
plt.grid()
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9788\2572208033.py:2: FutureWarning: 'y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   yearly = df[columns].resample('y').sum()

# %%
# https://stackoverflow.com/questions/30133280/pandas-bar-plot-changes-date-format
# import datetime
    
columns = ['Solar','Wind']
yearly = df[columns].resample('y').sum()
    
def line_format(datetime):
    """
    Convert time label to the format of pandas line plot
    """
    month = datetime.month_name()[:3]
    if month == 'Jan':
        month += f'\n{datetime.year}'
    lb = str(datetime.year) # + '/' + str(datetime.month)
    return lb

# Note that we specify rot here
# ax = df_year.Age.plot(kind='bar', figsize=(10, 3), color='#2ecc71', rot=0)
ax = yearly.plot(kind='bar', figsize=(12,3), rot=20)
ax.set_xticklabels(map(lambda x: line_format(x), yearly.index))
ax.set(xlabel="Date", ylabel="Power (GWh)")
ax.set(title="Yearly Power 2006-2018")
plt.grid()
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9788\1050820364.py:5: FutureWarning: 'y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   yearly = df[columns].resample('y').sum()
