# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

uri = 'data/treatment-nl.csv' 
df = pd.read_csv(uri)
df.head()
# df.tail(10)
df.sample(5)
# Out:
#      TA      TB  TC light region  product
# 532  28  35.435   0    no      N   359.57
# 727  18  25.175   0   yes      N  1551.82
# 690  60  27.550   0    no      N  3330.71
# 115  35  34.105   3   yes      W  6333.37
# 355  46  33.440   1    no      S  2076.63

# %%
df.info()
# df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 779 entries, 0 to 778
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   TA       779 non-null    int64
#  1   TB       779 non-null    float64
#  2   TC       779 non-null    int64
#  3   light    779 non-null    object
#  4   region   779 non-null    object
#  5   product  779 non-null    float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 36.6+ KB

# %%
df.isnull().sum()
# Out:
# TA         0
# TB         0
# TC         0
# light      0
# region     0
# product    0
# dtype: int64

# %%
df.describe().round(2)
# Out:
#            TA      TB      TC  product
# count  779.00  779.00  779.00   779.00
# mean    39.61   30.53    1.12  2118.05
# std     13.94    6.00    1.16  1526.58
# min     18.00   15.96    0.00   161.58
# 25%     27.00   26.22    0.00   734.21
# 50%     39.00   30.20    1.00  2085.07
# 75%     52.00   34.42    2.00  3063.99
# max     64.00   49.06    4.00  6579.54

# %%
sns.set_style('whitegrid')

plt.rcParams.update({'font.size':13})
sns.histplot(df['product'], color='b')
plt.show()

# %% [markdown]
# # scatter

# %%
# ws3
sns.set_style('whitegrid')
sns.scatterplot(x='TA', y='product', data=df)
# Out:
# <Axes: xlabel='TA', ylabel='product'>

# %%
sns.scatterplot(x='TB', y='product', data=df)
# Out:
# <Axes: xlabel='TB', ylabel='product'>

# %%
sns.scatterplot(x='TC', y='product', data=df)
# Out:
# <Axes: xlabel='TC', ylabel='product'>

# %%
sns.scatterplot(x='TA', y='product', data=df, label='TA') 
sns.scatterplot(x='TB', y='product', data=df, label='TB') 
sns.scatterplot(x='TC', y='product', data=df, label='TC') 

plt.legend(loc='lower right')

# %%
f, axes = plt.subplots(1, 3, figsize=(10, 3))
sns.scatterplot(x='TA',y='product',data=df, ax=axes[0])
sns.scatterplot(x='TB',y='product',data=df, ax=axes[1])
sns.scatterplot(x='TC',y='product',data=df, ax=axes[2])
# Out:
# <Axes: xlabel='TC', ylabel='product'>

# %%
f, axes = plt.subplots(2, 2, figsize=(8, 8))
sns.scatterplot(x='TA',y='product',data=df, ax=axes[0][0])
sns.scatterplot(x='TB',y='product',data=df, ax=axes[0][1])
sns.scatterplot(x='TC',y='product',data=df, ax=axes[1][0])
sns.histplot(df['product'], color='b', ax=axes[1][1])
# Out:
# <Axes: xlabel='product', ylabel='Count'>

# %%
# ws6
#sns.scatterplot(x='TA', y='product', data=df, hue='light') #ok dont have col split, legend inside
g = sns.relplot(x='TA', y='product', data=df, hue='light') #ok
g.figure.set_size_inches(6,4)

# %%
g = sns.relplot(x='TB', y='product', data=df, hue='light')

# %%
g = sns.relplot(x='TA', y='product', data=df, col='light')

# %%
sns.relplot(x='TA', y='product', data=df, col='light') # ok split column

# %%
sns.relplot(x='TB', y='product', col='light', data=df)

# %%
g = sns.relplot(x='TA', y='product', data=df, col='region', row='light') 
g.figure.set_size_inches(8, 4)

# %%
# ws7
sns.set_theme(style="ticks") 
# sns.set_style('whitegrid')

g = sns.jointplot(x='TA',y='product',data=df)

sns.set_theme(font_scale=1.5)

# %%
sns.set_theme(style="ticks") 
sns.jointplot(x='TA',y='product',data=df, kind='kde')

# %%
sns.jointplot(x='TA',y='product',data=df, kind='hex')

# %%
# sns.kdeplot(x='TA',y='product',data=df)
sns.kdeplot(x=df['TA'], y=df['product'])
plt.show()

# %%
sns.jointplot(x='TB',y='product',data=df, kind='kde')

# %%
sns.swarmplot(x='light', y='product', data=df)
# Out:
# <Axes: xlabel='light', ylabel='product'>
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:3399: UserWarning: 15.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='region', y='product', data=df)
# Out:
# <Axes: xlabel='region', ylabel='product'>
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:3399: UserWarning: 6.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#corr_val = df.corr()  
col = ['TA','TB','TC','product']
corr_val = df[col].corr().round(2)  
corr_val
# Out:
#            TA    TB    TC  product
# TA       1.00  0.11 -0.00     0.58
# TB       0.11  1.00  0.01     0.07
# TC      -0.00  0.01  1.00     0.04
# product  0.58  0.07  0.04     1.00

# %%
columns = ['TA','TB','product']
#columns = ['TA','TB','lig''product']
corr_val2 = df[columns].corr().round(2)
corr_val2
# Out:
#            TA    TB  product
# TA       1.00  0.11     0.58
# TB       0.11  1.00     0.07
# product  0.58  0.07     1.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 779 entries, 0 to 778
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   TA       779 non-null    int64
#  1   TB       779 non-null    float64
#  2   TC       779 non-null    int64
#  3   light    779 non-null    object
#  4   region   779 non-null    object
#  5   product  779 non-null    float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 36.6+ KB

# %%
df['lightnum'] = df['lightnum'].replace('yes',1)
df['lightnum'] = df['lightnum'].replace('no',0)

df.sample(10)
# Out:
#      TA      TB  TC light region  product  lightnum
# 585  49  35.860   0    no      S  2047.35         0
# 738  33  24.795   0   yes      N  2836.07         1
# 766  24  40.150   0   yes      S  4193.88         1
# 332  38  37.050   1    no      N   963.02         0
# 736  32  24.600   0   yes      E  2771.42         1
# 550  34  35.815   0    no      W   684.35         0
# 336  38  40.565   1    no      W  1009.58         0
# 220  50  23.540   2    no      S  2547.02         0
# 653  58  29.000   0    no      E  2984.28         0
# 90   56  32.300   3    no      N  3384.43         0

# %%
import numpy as np
df['lightnum'] = np.where(df.light.str.match('yes'), 1, 0)

# %%
df.sample(6)
# Out:
#      TA      TB  TC light region  product  lightnum
# 302  28  37.620   1    no      S   414.36         0
# 317  32  37.335   1    no      N   739.35         0
# 11   26  29.640   4    no      N  2713.89         0
# 55   40  35.300   3    no      E  1139.99         0
# 19   21  20.235   3    no      N   424.73         0
# 355  46  33.440   1    no      S  2076.63         0

# %%
pvt = df.pivot_table(index='light', columns=['region'], values=['lightnum'], aggfunc='count')
pvt
df.groupby('light').count()
# Out:
#         TA   TB   TC  region  product  lightnum
# light
# no     652  652  652     652      652       652
# yes    127  127  127     127      127       127

# %%
df.groupby('lightnum').count()
# Out:
#            TA   TB   TC  light  region  product
# lightnum
# 0         652  652  652    652     652      652
# 1         127  127  127    127     127      127

# %%
columns  = ['TA','TB','lightnum','product']
corr_val2 = df[columns].corr().round(2)
corr_val2
# Out:
#             TA    TB  lightnum  product
# TA        1.00  0.11     -0.21     0.58
# TB        0.11  1.00     -0.14     0.07
# lightnum -0.21 -0.14      1.00     0.53
# product   0.58  0.07      0.53     1.00

# %%
sns.heatmap(corr_val, annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
col = ['TA','TB','TC','product','lightnum']
corr_val = df[col].corr()
sns.heatmap(corr_val, annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# # pairplot

# %%
sns.set_theme(style="ticks") 

g = sns.pairplot(df)
g.figure.set_size_inches(8, 8)

# %%
columns = ['TA','TB','lightnum','product']

sns.pairplot(df[columns], height=2)

g.figure.set_size_inches(8, 8)

# %%
sns.set_theme(style="ticks") 

g = sns.pairplot(df, kind='reg', height=1.5)

# %%
sns.set(style="ticks") 

g = sns.pairplot(df, kind='reg', hue='light', height=2)

# %%
sns.set_style('ticks')

g=sns.lmplot(x='TA', y='product', data=df) 
sns.set_theme(font_scale=1.2)
g.figure.set_size_inches(5, 4)

# %%
g=sns.lmplot(x='TA', y='product', data=df, hue='light') 
g.figure.set_size_inches(6, 4)

# %%
g=sns.lmplot(x='TB', y='product', data=df) 
g.figure.set_size_inches(5, 4)

# %%
g=sns.lmplot(x='TB', y='product', data=df, hue='light')
g.figure.set_size_inches(5, 4)

# %%
g=sns.lmplot(x='TB', y='product', data=df, col='light') 
g.figure.set_size_inches(8, 4)

# %%
sns.lmplot(x='TA', y='product', data=df, hue='region')
