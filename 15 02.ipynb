# %%
X = [[27],                                                              
     [35],                                                              
     [39],                                                              
     [21],                                                              
     [22],                                                                   
     [45],
     [102],
     [110],
     [120] ]                                                              

y_names = ['lemon', 'orange', 'orange', 'lemon', 'lemon', 'orange', 'pamelo', 'pamelo', 'pamelo']
y = [0, 1, 1, 0, 0, 1, 2, 2, 2]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
y_le = LabelEncoder()
y = y_le.fit_transform(y_names)
y
# Out:
# array([0, 1, 1, 0, 0, 1, 2, 2, 2])

# %%
class_names = list(y_le.classes_)  # class names or fruit_types
class_names
# Out:
# [np.str_('lemon'), np.str_('orange'), np.str_('pamelo')]

# %%
X
# Out:
# [[27], [35], [39], [21], [22], [45], [102], [110], [120]]

# %%
y
# Out:
# array([0, 1, 1, 0, 0, 1, 2, 2, 2])

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder

X = [[27],                                                              
     [35],                                                              
     [39],                                                              
     [21],                                                              
     [22],                                                                   
     [45],
     [102],
     [110],
     [120],
    ]                                                              

y_names = ['lemon', 'orange', 'orange', 'lemon', 'lemon', 'orange', 'pamelo', 'pamelo', 'Pamelo']

# y = [0, 1, 1, 0, 0, 1, 2, 2, 2]
y_le = LabelEncoder()

y = y_le.fit_transform(y_names)

class_names = list(y_le.classes_)  # class names or fruit_types
print('all class: {}'. format(class_names))

model = DecisionTreeClassifier()
model.fit(X, y)

data = [[125]] # ทดสอบ 
y_predict = model.predict(data)

prd = class_names[y_predict[0]]
print('Result: size {} -> {}'. format(data[0],prd))
# Out:
# all class: [np.str_('Pamelo'), np.str_('lemon'), np.str_('orange'), np.str_('pamelo')]
# Result: size [125] -> Pamelo

# %%
data_feature_names = ['size']
fruit_types = class_names 

import pydotplus
from sklearn.tree import export_graphviz
from IPython.display import Image

dot_data = export_graphviz(model, out_file=None, 
                           feature_names=data_feature_names,  
                           class_names=fruit_types, # 
                           filled=True,
                           rounded=True)


graph = pydotplus.graph_from_dot_data(dot_data)  
Image(graph.create_png())
